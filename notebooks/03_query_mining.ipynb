# %% [markdown]
# # 03 — Query-driven hard-negative mining
# `src/` tek kaynak; bu notebook yalnız Kaggle çalıştırıcısıdır.

# %%
from pathlib import Path
import os, subprocess, sys
ROOT = Path('/kaggle/working/Kaggle_Trendyol') if Path('/kaggle').exists() else Path.cwd().parent
DATA = Path('/kaggle/input/trendyol-e-ticaret-yarismasi-2026') if Path('/kaggle').exists() else ROOT/'data'
cmd = [sys.executable, str(ROOT/'src/trendyol_query_hard_negative_mining.py'), '--data-dir', str(DATA), '--artifacts-dir', '/kaggle/working' if Path('/kaggle').exists() else str(ROOT/'artifacts'), '--experiment-id', 'query_mining_v2']
subprocess.run(cmd, check=True)
