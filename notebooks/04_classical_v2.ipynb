# %% [markdown]
# # 04 — Classical v2
# LightGBM + fielded TF-IDF + query-level features.

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path('/kaggle/working/Kaggle_Trendyol') if Path('/kaggle').exists() else Path.cwd().parent
DATA = Path('/kaggle/input/trendyol-e-ticaret-yarismasi-2026') if Path('/kaggle').exists() else ROOT/'data'
ART = Path('/kaggle/working') if Path('/kaggle').exists() else ROOT/'artifacts'
TRAIN = ART/'experiments/query_mining_v2/train_query_negatives.parquet'
subprocess.run([sys.executable, str(ROOT/'src/trendyol_train_classical_v2.py'), '--data-dir', str(DATA), '--artifacts-dir', str(ART), '--train', str(TRAIN), '--experiment-id', 'classical_v3'], check=True)
