# %% [markdown]
# # 02 — Baseline model eğitimi
#
# Lexical + TF-IDF feature'ları ve `HistGradientBoostingClassifier` ile relevance modeli.
#
# **Ön koşul:** `artifacts/train_with_negatives.parquet` (negatif örnekleme script'i)
#
# Yerel çalıştırma:
# ```bash
# make negatives   # ilk kez veya veri yenilenince
# make train
# ```

# %%
import os
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

os.environ.setdefault("DATA_DIR", str(ROOT / "data"))
os.environ.setdefault("ARTIFACTS_DIR", str(ROOT / "artifacts"))
os.environ.setdefault("USE_FULL_SUBMISSION", "true")
os.environ.setdefault("SUBMISSION_SAMPLE_SIZE", "200000")

print("ROOT:", ROOT)
print("TRAIN:", ROOT / "artifacts/train_with_negatives.parquet")

# %%
from trendyol_train_baseline import main

main()

# %%
import pandas as pd
from pathlib import Path

ARTIFACTS = ROOT / "artifacts"
print(pd.read_csv(ARTIFACTS / "baseline_cv_report.csv"))
print("\nThreshold:", (ARTIFACTS / "baseline_threshold.txt").read_text().strip())
print(pd.read_csv(ARTIFACTS / "submission.csv").head())
